# %% [raw]
# Question 1. Discuss the scenarios where multithreading is preferable to multiprocessing and scenarios where multiprocessing is a better choice.
#
# >> Both multithreading and multiprocessing are used to achieve parallelism in Python, but they have different use cases depending on the nature of the task and system resources.
#
# Multithreading is Preferable:
# Multithreading is best when tasks are I/O-bound (i.e., the program spends most of its time waiting for external operations like disk I/O or network operations). In these cases, threads can work concurrently without causing too much overhead. Some scenarios include:
#
# I/O-Bound Tasks:
#
# File operations: Reading/writing files or data streams.
# Network requests: Making HTTP requests, working with APIs, downloading files, etc.
# Database queries: Fetching and storing data from/to databases.
#
#
# Example:- If you're scraping websites and making many HTTP requests, you can have multiple threads sending requests concurrently, which improves performance since the program doesn't spend time waiting for the server's response.
#
# Shared Memory Space:- Low overhead of context switching: Threads share the same memory space, so switching between them is lightweight compared to processes.
#
# Less memory usage:- Since threads operate within the same memory, they don’t need separate memory blocks, which reduces memory overhead.
#
# GUIs:-Most GUI frameworks, such as Tkinter or Qt, are single-threaded and require that UI updates happen in the main thread. Background tasks, like fetching data or handling user input, can be run in separate threads to keep the interface responsive.
#
# Concurrency:- When you want tasks to execute seemingly at the same time but do not require true parallelism. For example, a web server that handles multiple connections (clients) but isn't necessarily running heavy computations for each.
#
# Drawbacks:- Python’s Global Interpreter Lock (GIL) prevents multiple threads from executing Python bytecode at the same time. Thus, multithreading is not suitable for CPU-bound tasks as it can't fully utilize multiple cores.
#
#
# Multiprocessing is Preferable>>
#
# Multiprocessing is better suited for CPU-bound tasks, where multiple CPU cores can be leveraged to improve performance. Some scenarios include:
#
# CPU-Bound Tasks:- Heavy computations: Mathematical calculations, matrix operations, data transformations.
# Image processing: Manipulating large images or applying filters.
# Machine learning model training: Performing parallel data training or working with large datasets.
#
# Example: If you need to perform parallel data processing (like video transcoding or complex numerical simulations), multiprocessing will allow you to divide the work across different CPU cores.
#
# Bypassing the GIL:- Python’s GIL does not apply to multiprocessing since each process runs its own Python interpreter and memory space. This allows you to fully utilize multiple CPU cores for true parallelism.
#
# Isolation and Fault Tolerance :-
#
# Separate memory space:- Each process has its own memory space, so they don’t interfere with each other. This isolation can be useful in cases where you don’t want shared state between tasks.
# Fault isolation:- If one process crashes, it won’t affect the others, unlike in threading where a crash in one thread might crash the entire program.
#
# Embarrassingly Parallel Workloads :- Tasks that can be divided into smaller independent units, each running in isolation. Examples include running simulations on different data sets, parallelizing scientific computations, or rendering frames in video processing.
#
# Drawbacks :-
#
# Higher memory usage: Each process has its own memory, which increases overhead.
# Slower inter-process communication (IPC): Communication between processes is slower than threads due to the need for message-passing mechanisms.

# %% [raw]
# Question 2. Describe what a process pool is and how it helps in managing multiple processes efficiently.
#
# A process pool is a programming abstraction that allows efficient management of multiple worker processes in parallel. It provides a pool of worker processes that can execute tasks concurrently, enabling better resource utilization and simplified process management. The pool maintains a set number of worker processes that are reused for different tasks rather than constantly creating and destroying new processes, which can be resource-intensive.
#
# Key Features of a Process Pool:
#
# 1. Fixed Number of Workers
# 2. Task Queue
# 3. Asynchronous Execution
# 4. Resource Efficiency
#
# How a Process Pool Helps in Managing Multiple Processes Efficiently:
# Reduced Process Creation Overhead
# Simplified Parallelism
# Automatic Load Balancing
# Resource Control:
# Parallelism Across Multiple Cores:
# Concurrency Management:

# %%
import multiprocessing

def square(n):
    return n * n

if __name__ == "__main__":
    with multiprocessing.Pool(processes=4) as pool:
        numbers = [1, 2, 3, 4, 5]
        results = pool.map(square, numbers)
    
    print(results)
# Out:
# [1, 4, 9, 16, 25]

# %% [raw]
# Question 3. Explain what multiprocessing is and why it is used in Python programs.
#
# Multiprocessing is a parallel computing technique that involves creating and managing multiple independent processes to execute tasks simultaneously. Each process runs in its own memory space and can execute independently on different CPU cores, enabling programs to perform multiple tasks concurrently and make full use of multicore processors.
#
# In Python, the multiprocessing module allows developers to create multiple processes easily and handle inter-process communication, synchronization, and task parallelism.
#
# Why Multiprocessing is Used in Python Programs:
#
# 1. Bypassing the Global Interpreter Lock (GIL):
# 2. Leveraging Multiple CPU Cores:
# 3. Isolated Memory Space:
# 4. Fault Tolerance and Stability:
# 5. Ideal for CPU-Bound Tasks:
# 6. Handling Large Workloads:

# %%
# Here is an example using the multiprocessing module to parallelize a CPU-bound task, such as calculating squares of numbers.

import multiprocessing

def calculate_square(number):
    return number * number

if __name__ == "__main__":
    pool = multiprocessing.Pool(processes=4) 
    numbers = [1, 2, 3, 4, 5]
    results = pool.map(calculate_square, numbers)

    pool.close()
    pool.join()

    print(results)
# Out:
# [1, 4, 9, 16, 25]

# %%
# Question 4- Write a Python program using multithreading where one thread adds numbers to a list, and another thread removes numbers from the list. Implement a mechanism to avoid race conditions using threading.Lock.

import threading
import time
import random

# Shared resource (list)
numbers = []

# Create a lock object
lock = threading.Lock()

# Function to add numbers to the list
def add_numbers():
    global numbers
    for i in range(10):
        time.sleep(random.uniform(0.1, 0.5))  # Simulate some processing time
        lock.acquire()  # Acquire the lock before modifying the list
        try:
            number = random.randint(1, 100)
            numbers.append(number)
            print(f"Added {number} to the list: {numbers}")
        finally:
            lock.release()  # Always release the lock, even if an exception occurs

# Function to remove numbers from the list
def remove_numbers():
    global numbers
    for i in range(10):
        time.sleep(random.uniform(0.1, 0.5))  # Simulate some processing time
        lock.acquire()  # Acquire the lock before modifying the list
        try:
            if numbers:
                removed_number = numbers.pop(0)
                print(f"Removed {removed_number} from the list: {numbers}")
        finally:
            lock.release()  # Always release the lock, even if an exception occurs

# Create two threads: one for adding and one for removing
thread1 = threading.Thread(target=add_numbers)
thread2 = threading.Thread(target=remove_numbers)

# Start the threads
thread1.start()
thread2.start()

# Wait for both threads to complete
thread1.join()
thread2.join()

print("Final list:", numbers)
# Out:
# Added 46 to the list: [46]
# Removed 46 from the list: []
# Added 89 to the list: [89]
# Removed 89 from the list: []
# Added 50 to the list: [50]
# Removed 50 from the list: []
# Added 12 to the list: [12]
# Removed 12 from the list: []
# Added 73 to the list: [73]
# Removed 73 from the list: []
# Added 84 to the list: [84]
# Removed 84 from the list: []
# Added 43 to the list: [43]
# Removed 43 from the list: []
# Added 20 to the list: [20]
# Added 97 to the list: [20, 97]
# Added 15 to the list: [20, 97, 15]
# Final list: [20, 97, 15]

# %% [raw]
# Question 5. Describe the methods and tools available in Python for safely sharing data between threads and processes.
#
# In Python, when working with multithreading or multiprocessing, safely sharing data between threads or processes is crucial to avoid issues such as race conditions, inconsistent data, and other concurrency problems. Python provides various tools and methods to manage shared data safely.
#
# Sharing Data Between Threads:-
#
# In multithreading, threads share the same memory space, which makes it easier to share data. However, race conditions can occur if multiple threads try to modify the shared data concurrently. To handle this safely, Python provides synchronization primitives like locks, queues, and semaphores.
#
#
# 1. threading.Lock (Mutex)
# A Lock is the simplest synchronization primitive in Python. It allows only one thread to access a shared resource at a time. When one thread acquires the lock, other threads are blocked from modifying the resource until the lock is released.
#
# 2. threading.RLock (Reentrant Lock)
# An RLock (reentrant lock) allows a thread to acquire the same lock multiple times. This is useful if a thread needs to call a function that might try to acquire the same lock again (like recursive functions).
#
# 3. threading.Semaphore
# A Semaphore is a more flexible lock mechanism. It allows a certain number of threads to access the resource at once, useful when you want to limit access to a resource (e.g., limiting the number of threads that access a database).
#
# 4. threading.Event
# An Event is a simple way to communicate between threads. One thread can signal an event to notify other threads to continue execution. It's useful when one thread needs to wait for another to complete a task.
#
# 5. queue.Queue
# The Queue is a thread-safe FIFO (First In, First Out) data structure. It allows multiple threads to add or remove items in a safe way without needing explicit locks. It is useful for producer-consumer scenarios.
#
#
# Sharing Data Between Processes:-
#
# In multiprocessing, each process has its own memory space, so data is not shared between processes by default. If processes need to share data, specific mechanisms must be used. These include shared memory, pipes, and queues.
#
# 1. multiprocessing.Queue
# The Queue in the multiprocessing module works similarly to the queue.Queue, but it is designed for inter-process communication. It allows processes to safely pass data between them.
#
# 2. multiprocessing.Pipe
# Pipe allows a bi-directional communication channel between two processes. A pair of connected objects (conn1 and conn2) are created, where one process can send data via one end and another can receive it from the other end.
#
# 3. multiprocessing.Manager
# Manager provides a high-level way to create shared objects such as lists, dictionaries, etc., that can be safely shared and modified by multiple processes.
#
# 4. multiprocessing.Value and multiprocessing.Array
# Value and Array allow sharing of simple data types (e.g., integers, floats) and arrays between processes by placing them in shared memory.
# Value: Used for sharing a single value.
# Array: Used for sharing an array of values.
#
# 5. multiprocessing.Lock
# A Lock is used in the multiprocessing module to ensure that only one process can access a shared resource at a time, similar to the threading lock.

# %% [raw]
# Question 6. Discuss why it’s crucial to handle exceptions in concurrent programs and the techniques available for doing so.
#
# Handling exceptions in concurrent programs (such as those using multithreading or multiprocessing) is crucial for maintaining the stability, reliability, and correctness of applications. Concurrency introduces complexities like race conditions, deadlocks, and resource contention, making error handling more challenging than in single-threaded or single-process programs. Unhandled exceptions in concurrent programs can lead to issues such as orphaned threads/processes, resource leaks, corrupted data, and application crashes.
#
# Why Handling Exceptions in Concurrent Programs is Crucial:
#
# 1. Preventing Program Crashes:
#
# In concurrent programs, if an exception occurs and is not handled, the entire thread or process may terminate prematurely. In some cases, this can lead to the crashing of the whole application, especially if critical components are affected.
#
# 2. Avoiding Deadlocks and Resource Leaks:
#
# In a concurrent environment, unhandled exceptions can cause deadlocks if threads or processes do not release locks or other resources before terminating. This can leave shared resources in an inconsistent state and block other threads or processes from accessing them.
# For instance, a thread holding a lock could terminate unexpectedly due to an exception, preventing other threads from acquiring the lock and causing a deadlock.
#
# 3.Data Corruption and Inconsistent States:
#
# In concurrent programs, multiple threads or processes often share data. If one thread or process encounters an exception while modifying shared data, it may leave the data in an inconsistent or corrupted state, which can affect other parts of the program that rely on that data.
#
# 4.Improving Debugging and Maintenance:
#
# Concurrent programs are inherently more complex to debug than single-threaded programs. Without proper exception handling, debugging becomes even more difficult since exceptions may occur asynchronously in different threads or processes. Handling exceptions properly makes it easier to diagnose and fix issues.
#
# 5.Ensuring Application Robustness:
#
# By catching and handling exceptions, you can log errors, clean up resources, and ensure that the application continues to function correctly or fails gracefully without leaving the system in an unstable state.
#
# Techniques for Handling Exceptions in Concurrent Programs:
#
# Python provides several techniques and strategies to handle exceptions in concurrent programs, both for multithreading and multiprocessing. Let’s look at them.
#
# 1. Exception Handling in Multithreading
# In multithreading, exceptions can occur in any thread, but handling them properly is essential to avoid terminating the whole program.
#
# a) Using Try-Except Blocks in Threads
# The simplest way to handle exceptions in multithreaded programs is to wrap thread functions in try-except blocks. This ensures that any exception raised in the thread is caught and handled.
#
# b) Handling Exceptions in the Main Thread
# Sometimes, you want to propagate exceptions raised in threads back to the main thread. This can be achieved by storing the exception in a shared variable or using a custom thread class that catches the exception and raises it in the main thread.
#
# c) Using concurrent.futures.ThreadPoolExecutor
# The concurrent.futures.ThreadPoolExecutor class provides a high-level interface for managing threads. It also offers built-in exception handling by raising exceptions in the main thread when calling result() on a Future object.
#
# 2. Exception Handling in Multiprocessing
# In multiprocessing, each process runs in its own memory space, so exceptions that occur in one process are not directly propagated to others. Proper exception handling is crucial to avoid leaving resources in an inconsistent state.
#
# a) Using Try-Except Blocks in Processes
# Just like in multithreading, you can handle exceptions within each process by wrapping the process function in a try-except block.
#
# b) Using multiprocessing.Pool for Exception Handling
# The multiprocessing.Pool class provides a way to handle exceptions in parallel processing. When you use the apply, map, or apply_async methods, any exception raised in a worker process is propagated back to the parent process, where it can be caught.
#
# c) Handling Exceptions in concurrent.futures.ProcessPoolExecutor
# Similar to ThreadPoolExecutor, ProcessPoolExecutor handles exceptions automatically. The exceptions are propagated to the main process when calling the result() method on a Future object.
#
# d) Propagating Exceptions Manually via IPC (Queues or Pipes)
# In some cases, you may need to manually propagate exceptions between processes. This can be done using Inter-Process Communication (IPC) mechanisms like queues or pipes.

# %%
# Question 7. Create a program that uses a thread pool to calculate the factorial of numbers from 1 to 10 concurrently. Use concurrent.futures.ThreadPoolExecutor to manage the threads.

import concurrent.futures
import math

# Function to calculate factorial
def calculate_factorial(n):
    print(f"Calculating factorial of {n}")
    return math.factorial(n)

# List of numbers from 1 to 10
numbers = list(range(1, 11))

# Using ThreadPoolExecutor to manage threads
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submitting the factorial tasks to the thread pool
    futures = [executor.submit(calculate_factorial, num) for num in numbers]
    
    # Collecting and printing the results as they are completed
    for future in concurrent.futures.as_completed(futures):
        result = future.result()
        print(f"Factorial calculated: {result}")
# Out:
# Calculating factorial of 1
# Calculating factorial of 2
# Calculating factorial of 3
# Calculating factorial of 4
# Calculating factorial of 5
# Calculating factorial of 6
# Calculating factorial of 7
# Calculating factorial of 8
# Calculating factorial of 9
# Calculating factorial of 10
# Factorial calculated: 24
# Factorial calculated: 3628800
# Factorial calculated: 6
# Factorial calculated: 5040
# Factorial calculated: 362880
# Factorial calculated: 720
# Factorial calculated: 40320
# Factorial calculated: 2
# Factorial calculated: 120
# Factorial calculated: 1

# %%
# Question 8. Create a Python program that uses multiprocessing.Pool to compute the square of numbers from 1 to 10 in parallel. Measure the time taken to perform this computation using a pool of different sizes (e.g., 2, 4, 8 processes).

import multiprocessing
import time

# Function to compute the square of a number (with added computational load)
def compute_square(n):
    # Simulate a CPU-bound task
    total = 0
    for _ in range(1000000):
        total += n * n
    return total

if __name__ == "__main__":
    numbers = list(range(1, 11))  # Numbers from 1 to 10
    pool_sizes = [2, 4, 8]        # Different pool sizes to test

    for size in pool_sizes:
        # Create a pool with the specified number of processes
        pool = multiprocessing.Pool(processes=size)
        start_time = time.perf_counter()  # Start the timer

        # Use the pool to compute the squares in parallel
        results = pool.map(compute_square, numbers)

        pool.close()
        pool.join()  # Wait for all processes to finish
        end_time = time.perf_counter()  # End the timer

        print(f"Pool size: {size}, Time taken: {end_time - start_time:.4f} seconds")

    print("Computation results:", results)
# Out:
# Pool size: 2, Time taken: 0.4951 seconds
# Pool size: 4, Time taken: 0.2449 seconds
# Pool size: 8, Time taken: 0.1699 seconds
# Computation results: [1000000, 4000000, 9000000, 16000000, 25000000, 36000000, 49000000, 64000000, 81000000, 100000000]
